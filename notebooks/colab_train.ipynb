# %%
# !git clone https://github.com/FractalMachinist/datr.git
# !cd datr && git pull
# Out:
# Cloning into 'datr'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 24 (delta 11), reused 21 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 18.66 KiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Already up to date.

# %%
# !apt-get remove python3-blinker
# %pip install torch transformers pandas numpy wandb tqdm
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   distro-info-data gir1.2-packagekitglib-1.0 libappstream4 libdw1
#   libgstreamer1.0-0 libpackagekit-glib2-18 libpolkit-agent-1-0
#   libpolkit-gobject-1-0 libstemmer0d libxmlb2 libyaml-0-2 lsb-release
#   packagekit pkexec policykit-1 polkitd python-apt-common python3-apt
#   python3-cffi-backend python3-cryptography python3-dbus python3-distro
#   python3-gi python3-httplib2 python3-jeepney python3-jwt python3-keyring
#   python3-lazr.uri python3-pkg-resources python3-pyparsing
#   python3-secretstorage python3-six python3-wadllib
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   python3-blinker python3-launchpadlib python3-lazr.restfulclient
#   python3-oauthlib python3-software-properties software-properties-common
# ...

# %%
import os
import sys
sys.path.append("datr/src")

# %%
from train_trait_llm import main

# %%
main()
# Out:
# Using device: cpu
# Loading dataset...
# Dataset not found at /content/datr/downloads/okcupid_profiles.csv
# ...
# Extracting to /content/datr/downloads...
# Dataset downloaded and extracted successfully to /content/datr/downloads/okcupid_profiles.csv
# Dataset found at /content/datr/downloads/okcupid_profiles.csv
# Loading dataset from /content/datr/downloads/okcupid_profiles.csv...
#   Processed 10000 profiles, 81152 essays so far...
#   Processed 20000 profiles, 162393 essays so far...
#   Processed 30000 profiles, 243962 essays so far...
#   Processed 40000 profiles, 324933 essays so far...
#   Processed 50000 profiles, 405595 essays so far...
#
# Dataset loaded: 485848 (trait_vector, essay_text) pairs
#   From 59946 profiles
#   Text lengths: min=17, max=36543, mean=281
# Dataset split: 388678 train, 97170 val
# Loading model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# ...
